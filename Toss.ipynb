# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd

# %%
df1 = pd.read_csv('archive/matches.csv')
df1.dataframeName = 'matches.csv'

# %%
df1.head(5)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# Is the toss that important in T20 games, does chasing have a significant advantage
#
# Find out toss outcomes and game outcomes in specific venues
# Just click the drop down list box and choose the stadium
# You will find the what the majority of teams winning the toss here have chosen to do.
# You will also see the percentage of matches won by the team that won the toss

# %%
len(df1)
# Out:
# 636

# %%
venue_subset = df1[df1["venue"] == 'M Chinnaswamy Stadium']
venue_subset
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 16    17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 29    30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# 41    42    2017  Bangalore  2017-05-05              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 616  617    2016  Bangalore  2016-05-11  Royal Challengers Bangalore
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 625  626    2016  Bangalore  2016-05-18  Royal Challengers Bangalore
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
total_games = len(venue_subset)
total_games
# Out:
# 66

# %%
toss_outcome = venue_subset[ venue_subset ["toss_winner"]== venue_subset["winner"] ]

# %%
toss_winners = len(toss_outcome)
toss_winners
# Out:
# 36

# %%
percentage = toss_winners / total_games * 100

# %%
percentage
# Out:
# 54.54545454545454

# %%
percent = len(venue_subset [venue_subset["toss_decision"]=='field']) / total_games * 100
percent
# Out:
# 86.36363636363636

# %% [markdown]
# Find out the trends of the ongoing season of IPL - bat first / bowl first

# %%
season_subset = df1 [ df1["season"] == 2017]
season_subset
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
total_games = len(season_subset)
total_games
# Out:
# 59

# %%
season_trends = len(season_subset[ season_subset ["toss_winner"] == season_subset["winner"] ])
percentage = season_trends / total_games * 100
percentage
# Out:
# 57.6271186440678

# %%
percent = len(season_subset [season_subset["toss_decision"] =='field']) / total_games * 100
percent
# Out:
# 81.35593220338984

# %% [markdown]
# Find out if your team wins if they win the toss. Also, find out how much your team wins the toss.

# %%
team_trends = df1 [ df1 ["team1"] == "Royal Challengers Bangalore"]
team_trends2 = df1 [ df1["team2"] == "Royal Challengers Bangalore"] 

total = len(team_trends) + len(team_trends2)

team = len(team_trends[ team_trends ["toss_winner"] == "Royal Challengers Bangalore"])
team = team + len(team_trends2 [team_trends2 ["toss_winner"] == "Royal Challengers Bangalore"])

total_toss_wins = team 
percentage = team / total * 100
percentage
# Out:
# 46.05263157894737

# %%
team = team_trends[ team_trends ["toss_winner"] == "Royal Challengers Bangalore"]
team2 = team_trends2 [team_trends2 ["toss_winner"] == "Royal Challengers Bangalore"]

team_wins = team_wins + len(team2 [ team2 ["winner"] == "Royal Challengers Bangalore"])

percentage = team_wins / total_toss_wins * 100
percentage
# Out:
# 50.0

# %% [markdown]
# Find the strength of your opposition. Are they a SRH or a GT

# %%
team_trends = df1 [ df1 ["team1"] == "Sunrisers Hyderabad"]
team_wins_bat = len(team_trends [ team_trends[ "winner"] == "Sunrisers Hyderabad"])

team_trends2 = df1 [ df1 ["team2"] == "Sunrisers Hyderabad"]
team_wins_bowl = len(team_trends [ team_trends[ "winner"] == "Sunrisers Hyderabad"])


total = team_wins_bat + team_wins_bowl

p1 = team_wins_bat / total * 100

p1

p2 = team_wins_bowl / total * 100

p2
# Out:
# 50.0
